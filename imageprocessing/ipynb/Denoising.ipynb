# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
from skimage.io import imread, imshow

img = cv.imread('../data/1.jpg')
img = cv.cvtColor(img, cv.COLOR_GRAY2BGR)

dst = cv.fastNlMeansDenoisingColored(img,None,10,10,7,21)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-2-89d56d7cc0c6> in <module>
#       5
#       6 img = cv.imread('../data/1.jpg')
# ----> 7 img = cv.cvtColor(img, cv.COLOR_GRAY2BGR)
#       8
#       9 dst = cv.fastNlMeansDenoisingColored(img,None,10,10,7,21)
#
# error: OpenCV(4.2.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<1>; VDcn = cv::impl::{anonymous}::Set<3, 4>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 3

# %%
plt.subplot(121),plt.imshow(img)
img = cv.cvtColor(img, cv.COLOR_GRAY2BGR)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-13-b6d935ba488d> in <module>
#       1 img = cv.imread('../data/1.jpg')
#       2 plt.subplot(121),plt.imshow(img)
# ----> 3 img = cv.cvtColor(img, cv.COLOR_GRAY2BGR)
#
# error: OpenCV(4.2.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<1>; VDcn = cv::impl::{anonymous}::Set<3, 4>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 3

# %%
img = cv.imread('../data/3.jpg')

dst = cv.fastNlMeansDenoisingColored(src=img, dst=None, h=7, hColor=10, 
                                     templateWindowSize=7, searchWindowSize=21)
plt.figure(figsize=(10, 10))
plt.subplot(121),plt.imshow(img)
plt.subplot(122),plt.imshow(dst)
plt.show()

# %%
type(dst)
# Out:
# numpy.ndarray

# %%
import skimage.io as sk
sk.imsave("../data/1_denoise.jpg", dst)
